# %% [markdown]
# # Regression of Vote Characteristics on CAR

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 19.5
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2025 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user 2-core network, expiring  9 Sep 2026
# Serial number: 501909305069
#   Licensed to: 罗奕辰
#                UCL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
# clear all
# set more off
# set varabbrev off
# version 18
#
# * Paths
# global PROCESSED_DATA "processed_data"
# global TABLES "tables"
# Out:
# .
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# . version 18
#
# .
# . * Paths
# . global PROCESSED_DATA "processed_data"
#
# . global TABLES "tables"
#
# .

# %%
# %%stata
# foreach stage in created end {
#     import delimited using "$PROCESSED_DATA/event_study_panel_`stage'.csv", clear
#
#     * Parse date
#     gen day = date(date, "YMD")
#     format day %td
#
#     * Create year variable
#     gen year = year(day)
#
#     * Create quarter variable
#     gen quarter = qofd(day)
#     format quarter %tq
#
#     * Ensure index is numeric (safeguard if it came in as string)
#     capture confirm numeric variable index
#     if _rc {
#         destring index, replace ignore("[]")
#     }
#
#     * Encode categorical variables
#     encode gecko_id, gen(token)
#     encode space,    gen(dao)
#
#     egen token_year = group(token year)
#     egen token_quarter = group(token quarter)
#
#     * Define windows and specs
#     local window 5
#     local vars user_incentive_increase treasury_expenditure voting_mechanism_change protocol_security tokenomics
#
#     * Label variables
#
#     eststo clear
#
#     keep if index == `window'
#
#     foreach v of local vars {
#
#         * Run regression
#         reghdfe car `v', absorb(year dao) vce(cluster token)
#         eststo car_`v'
#
#         * Tag FE rows (Y/N) for this spec
#         estadd local fe_token "Y"
#         estadd local fe_time  "Y"
#     }
#
#     * Export a single big LaTeX table
#     esttab                                                         ///
#         car_user_incentive_increase car_treasury_expenditure car_voting_mechanism_change car_protocol_security car_tokenomics   ///
#         using "$TABLES/reg_car_topic_`stage'.tex", replace         ///
#         se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///
#         nonotes booktabs nomtitles                                 ///
#         b(%9.3f) se(%9.2f)                                         ///
#         mgroups("CAR[-5,5]",                                       ///
#                 span                                               ///
#                 pattern(1 0 0 0)                                     ///
#                 prefix(\multicolumn{@span}{c}{)                    ///
#                 suffix(})                                          ///
#                 erepeat(\cmidrule(lr){@span}) )                    ///
#         substitute("\_" "_")                                       ///
#         stats(fe_token fe_time N r2_a,                             ///
#               fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Observations" "Adjusted R²"))
# }
# Out:
# . foreach stage in created end {
#   2.     import delimited using "$PROCESSED_DATA/event_study_panel_`stage'.csv"
# > , clear
#   3.
# .     * Parse date
# .     gen day = date(date, "YMD")
#   4.     format day %td
#   5.
# .     * Create year variable
# .     gen year = year(day)
#   6.
# .     * Create quarter variable
# .     gen quarter = qofd(day)
#   7.     format quarter %tq
#   8.
# .     * Ensure index is numeric (safeguard if it came in as string)
# .     capture confirm numeric variable index
#   9.     if _rc {
#  10.         destring index, replace ignore("[]")
#  11.     }
#  12.
# .     * Encode categorical variables
# .     encode gecko_id, gen(token)
#  13.     encode space,    gen(dao)
#  14.
# .     egen token_year = group(token year)
#  15.     egen token_quarter = group(token quarter)
#  16.
# .     * Define windows and specs
# .     local window 5
#  17.     local vars user_incentive_increase treasury_expenditure voting_mechani
# > sm_change protocol_security tokenomics
#  18.
# .     * Label variables
# .
# .     eststo clear
#  19.
# .     keep if index == `window'
#  20.
# .     foreach v of local vars {
#  21.
# .         * Run regression
# .         reghdfe car `v', absorb(year dao) vce(cluster token)
#  22.         eststo car_`v'
#  23.
# .         * Tag FE rows (Y/N) for this spec
# .         estadd local fe_token "Y"
#  24.         estadd local fe_time  "Y"
#  25.     }
#  26.
# .     * Export a single big LaTeX table
# .     esttab                                                         ///
# >         car_user_incentive_increase car_treasury_expenditure car_voting_mecha
# > nism_change car_protocol_security car_tokenomics   ///
# >         using "$TABLES/reg_car_topic_`stage'.tex", replace         ///
# >         se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///
# >         nonotes booktabs nomtitles                                 ///
# >         b(%9.3f) se(%9.2f)                                         ///
# >         mgroups("CAR[-5,5]",                                       ///
# >                 span                                               ///
# >                 pattern(1 0 0 0)                                     ///
# >                 prefix(\multicolumn{@span}{c}{)                    ///
# >                 suffix(})                                          ///
# >                 erepeat(\cmidrule(lr){@span}) )                    ///
# >         substitute("\_" "_")                                       ///
# >         stats(fe_token fe_time N r2_a,                             ///
# >               fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Observations
# > " "Adjusted R²"))
#  27. }
# (encoding automatically selected: ISO-8859-1)
# (20 vars, 17,435 obs)
# (15,850 observations deleted)
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.07
# Statistics robust to heteroskedasticity           Prob > F        =     0.7930
#                                                   R-squared       =     0.2366
#                                                   Adj R-squared   =     0.2137
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# user_incen~e |  -.0041026   .0155245    -0.26   0.793    -.0355303     .027325
#        _cons |   -.018247   .0043555    -4.19   0.000    -.0270643   -.0094298
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.02
# Statistics robust to heteroskedasticity           Prob > F        =     0.8919
#                                                   R-squared       =     0.2366
#                                                   Adj R-squared   =     0.2137
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# treasury_e~e |   .0017215   .0125859     0.14   0.892    -.0237573    .0272004
#        _cons |   -.020351   .0069665    -2.92   0.006    -.0344539    -.006248
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.11
# Statistics robust to heteroskedasticity           Prob > F        =     0.7371
#                                                   R-squared       =     0.2366
#                                                   Adj R-squared   =     0.2137
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# voting_mec~e |  -.0078561   .0232341    -0.34   0.737     -.054891    .0391788
#        _cons |  -.0189901   .0012066   -15.74   0.000    -.0214327   -.0165475
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('stata', '', 'foreach stage in created end {\n    import delimited using "$PROCESSED_DATA/event_study_panel_`stage\'.csv", clear\n\n    * Parse date\n    gen day = date(date, "YMD")\n    format day %td\n\n    * Create year variable\n    gen year = year(day)\n\n    * Create quarter variable\n    gen quarter = qofd(day)\n    format quarter %tq\n\n    * Ensure index is numeric (safeguard if it came in as string)\n    capture confirm numeric variable index\n    if _rc {\n        destring index, replace ignore("[]")\n    }\n\n    * Encode categorical variables\n    encode gecko_id, gen(token)\n    encode space,    gen(dao)\n\n    egen token_year = group(token year)\n    egen token_quarter = group(token quarter)\n\n    * Define windows and specs\n    local window 5\n    local vars user_incentive_increase treasury_expenditure voting_mechanism_change protocol_security tokenomics\n\n    * Label variables\n\n    eststo clear\n\n    keep if index == `window\'\n\n    foreach v of local vars {\n\n        * Run regression\n        reghdfe car `v\', absorb(year dao) vce(cluster token)\n        eststo car_`v\'\n\n        * Tag FE rows (Y/N) for this spec\n        estadd local fe_token "Y"\n        estadd local fe_time  "Y"\n    }\n\n    * Export a single big LaTeX table\n    esttab                                                         ///\n        car_user_incentive_increase car_treasury_expenditure car_voting_mechanism_change car_protocol_security car_tokenomics   ///\n        using "$TABLES/reg_car_topic_`stage\'.tex", replace         ///\n        se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///\n        nonotes booktabs nomtitles                                 ///\n        b(%9.3f) se(%9.2f)                                         ///\n        mgroups("CAR[-5,5]",                                       ///\n                span                                               ///\n                pattern(1 0 0 0)                                     ///\n                prefix(\\multicolumn{@span}{c}{)                    ///\n                suffix(})                                          ///\n                erepeat(\\cmidrule(lr){@span}) )                    ///\n        substitute("\\_" "_")                                       ///\n        stats(fe_token fe_time N r2_a,                             ///      \n              fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Observations" "Adjusted R²"))\n}\n')
#
# File ~/Desktop/research/dao-governance/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /Applications/StataNow/utilities/pystata/ipython/stpymagic.py:289, in PyStataMagic.stata(self, line, cell, local_ns)
#     287     _stata.run(cell, quietly=True, echo=echo, inline=_config.stconfig['grshow'])
#     288 else:
# --> 289     _stata.run(cell, quietly=False, echo=echo, inline=_config.stconfig['grshow'])
#     291 if '-gw' in args or '-gh' in args:
#     292     _config.set_graph_size(gwidth, gheight)
#
# File /Applications/StataNow/utilities/pystata/stata.py:361, in run(cmd, quietly, echo, inline)
#     359         _stata_wrk2("qui include " + tmpf, None, False, 1, echo)
#     360     else:
# --> 361         _stata_wrk2("include " + tmpf, None, False, 1, echo)
#     363 if inline:
#     364     if config.get_stipython()>=3:
#
# File /Applications/StataNow/utilities/pystata/stata.py:116, in _stata_wrk2(cmd, real_cmd, colon, mode, echo)
#     114         err = callback[0]
#     115         callback.clear()
# --> 116         raise SystemError(err)
#     117 except KeyboardInterrupt:
#     118     outputter.done()
#
# SystemError: -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       4.19
# Statistics robust to heteroskedasticity           Prob > F        =     0.0477
#                                                   R-squared       =     0.2387
#                                                   Adj R-squared   =     0.2158
#                                                   Within R-sq.    =     0.0027
# Number of clusters (token)   =         39         Root MSE        =     0.2380
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# protocol_s~y |  -.0380171   .0185832    -2.05   0.048    -.0756369   -.0003973
#        _cons |  -.0146068    .002342    -6.24   0.000     -.019348   -.0098656
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# variable tokenomics not found
# r(111);
# r(111);
