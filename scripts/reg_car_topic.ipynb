# %% [markdown]
# # Regression of Vote Characteristics on CAR

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 19.5
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2025 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user 2-core network, expiring  9 Sep 2026
# Serial number: 501909305069
#   Licensed to: 罗奕辰
#                UCL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
# clear all
# set more off
# set varabbrev off
# version 18
#
# * Paths
# global PROCESSED_DATA "processed_data"
# global TABLES "tables"
# Out:
# .
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# . version 18
#
# .
# . * Paths
# . global PROCESSED_DATA "processed_data"
#
# . global TABLES "tables"
#
# .

# %%
# %%stata
# foreach stage in created end {
#     import delimited using "$PROCESSED_DATA/event_study_panel_`stage'.csv", clear
#
#     * Parse date
#     gen day = date(date, "YMD")
#     format day %td
#
#     * Create year variable
#     gen year = year(day)
#
#     * Create quarter variable
#     gen quarter = qofd(day)
#     format quarter %tq
#
#     * Ensure index is numeric (safeguard if it came in as string)
#     capture confirm numeric variable index
#     if _rc {
#         destring index, replace ignore("[]")
#     }
#
#     * Encode categorical variables
#     encode gecko_id, gen(token)
#     encode space,    gen(dao)
#
#     egen token_year = group(token year)
#     egen token_quarter = group(token quarter)
#
#     * Define windows and specs
#     local window 5
#     local vars user_incentive_increase treasury_expenditure voting_mechanism_change protocol_security tokenomics
#
#     * Label variables
#
#     eststo clear
#
#     keep if index == `window'
#
#     foreach v of local vars {
#
#         * Run regression
#         reghdfe car `v', absorb(year dao) vce(cluster token)
#         eststo car_`v'
#
#         * Tag FE rows (Y/N) for this spec
#         estadd local fe_token "Y"
#         estadd local fe_time  "Y"
#     }
#
#     * Export a single big LaTeX table
#     esttab                                                         ///
#         car_user_incentive_increase car_treasury_expenditure car_voting_mechanism_change car_protocol_security car_tokenomics   ///
#         using "$TABLES/reg_car_topic_`stage'.tex", replace         ///
#         se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///
#         nonotes booktabs nomtitles                                 ///
#         b(%9.3f) se(%9.2f)                                         ///
#         mgroups("CAR[-5,5]",                                       ///
#                 span                                               ///
#                 pattern(1 0 0 0)                                     ///
#                 prefix(\multicolumn{@span}{c}{)                    ///
#                 suffix(})                                          ///
#                 erepeat(\cmidrule(lr){@span}) )                    ///
#         substitute("\_" "_")                                       ///
#         stats(fe_token fe_time N r2_a,                             ///
#               fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Observations" "Adjusted R²"))
# }
# Out:
# . foreach stage in created end {
#   2.     import delimited using "$PROCESSED_DATA/event_study_panel_`stage'.csv"
# > , clear
#   3.
# .     * Parse date
# .     gen day = date(date, "YMD")
#   4.     format day %td
#   5.
# .     * Create year variable
# .     gen year = year(day)
#   6.
# .     * Create quarter variable
# .     gen quarter = qofd(day)
#   7.     format quarter %tq
#   8.
# .     * Ensure index is numeric (safeguard if it came in as string)
# .     capture confirm numeric variable index
#   9.     if _rc {
#  10.         destring index, replace ignore("[]")
#  11.     }
#  12.
# .     * Encode categorical variables
# .     encode gecko_id, gen(token)
#  13.     encode space,    gen(dao)
#  14.
# .     egen token_year = group(token year)
#  15.     egen token_quarter = group(token quarter)
#  16.
# .     * Define windows and specs
# .     local window 5
#  17.     local vars yield_increase treasury_expenditure voting_mechanism_change
# >  protocol_security tokenomics
#  18.
# .     * Label variables
# .
# .     eststo clear
#  19.
# .     keep if index == `window'
#  20.
# .     foreach v of local vars {
#  21.
# .         * Run regression
# .         reghdfe car `v', absorb(year dao) vce(cluster token)
#  22.         eststo car_`v'
#  23.
# .         * Tag FE rows (Y/N) for this spec
# .         estadd local fe_token "Y"
#  24.         estadd local fe_time  "Y"
#  25.     }
#  26.
# .     * Export a single big LaTeX table
# .     esttab                                                         ///
# >         car_yield_increase car_treasury_expenditure car_voting_mechanism_chan
# > ge car_protocol_security car_tokenomics   ///
# >         using "$TABLES/reg_car_topic_`stage'.tex", replace         ///
# >         se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///
# >         nonotes booktabs nomtitles                                 ///
# >         b(%9.3f) se(%9.2f)                                         ///
# >         mgroups("CAR[-5,5]",                                       ///
# >                 span                                               ///
# >                 pattern(1 0 0 0)                                     ///
# >                 prefix(\multicolumn{@span}{c}{)                    ///
# >                 suffix(})                                          ///
# >                 erepeat(\cmidrule(lr){@span}) )                    ///
# >         substitute("\_" "_")                                       ///
# >         stats(fe_token fe_time N r2_a,                             ///
# >               fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Observations
# > " "Adjusted R²"))
#  27. }
# (encoding automatically selected: ISO-8859-1)
# (34 vars, 17,435 obs)
# (15,850 observations deleted)
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.05
# Statistics robust to heteroskedasticity           Prob > F        =     0.8216
#                                                   R-squared       =     0.2366
#                                                   Adj R-squared   =     0.2137
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# yield_incr~e |   .0024153   .0106389     0.23   0.822     -.019122    .0239526
#        _cons |  -.0202026    .003544    -5.70   0.000    -.0273772   -.0130281
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.02
# Statistics robust to heteroskedasticity           Prob > F        =     0.8919
#                                                   R-squared       =     0.2366
#                                                   Adj R-squared   =     0.2137
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# treasury_e~e |   .0017215   .0125859     0.14   0.892    -.0237573    .0272004
#        _cons |   -.020351   .0069665    -2.92   0.006    -.0344539    -.006248
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.11
# Statistics robust to heteroskedasticity           Prob > F        =     0.7371
#                                                   R-squared       =     0.2366
#                                                   Adj R-squared   =     0.2137
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# voting_mec~e |  -.0078561   .0232341    -0.34   0.737     -.054891    .0391788
#        _cons |  -.0189901   .0012066   -15.74   0.000    -.0214327   -.0165475
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       4.19
# Statistics robust to heteroskedasticity           Prob > F        =     0.0477
#                                                   R-squared       =     0.2387
#                                                   Adj R-squared   =     0.2158
#                                                   Within R-sq.    =     0.0027
# Number of clusters (token)   =         39         Root MSE        =     0.2380
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# protocol_s~y |  -.0380171   .0185832    -2.05   0.048    -.0756369   -.0003973
#        _cons |  -.0146068    .002342    -6.24   0.000     -.019348   -.0098656
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 6 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,579
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.22
# Statistics robust to heteroskedasticity           Prob > F        =     0.6434
#                                                   R-squared       =     0.2367
#                                                   Adj R-squared   =     0.2138
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =         39         Root MSE        =     0.2383
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#   tokenomics |   .0061854    .013254     0.47   0.643     -.020646    .0330168
#        _cons |  -.0233545   .0084779    -2.75   0.009    -.0405171    -.006192
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (output written to tables/reg_car_topic_created.tex)
# (encoding automatically selected: ISO-8859-1)
# (34 vars, 18,084 obs)
# (16,440 observations deleted)
# (dropped 4 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,640
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.84
# Statistics robust to heteroskedasticity           Prob > F        =     0.3652
#                                                   R-squared       =     0.2214
#                                                   Adj R-squared   =     0.1989
#                                                   Within R-sq.    =     0.0011
# Number of clusters (token)   =         39         Root MSE        =     0.1928
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# yield_incr~e |  -.0160986   .0175673    -0.92   0.365    -.0516616    .0194645
#        _cons |  -.0363334   .0057415    -6.33   0.000    -.0479564   -.0247103
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 4 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,640
# Absorbing 2 HDFE groups                           F(   1,     38) =       1.76
# Statistics robust to heteroskedasticity           Prob > F        =     0.1927
#                                                   R-squared       =     0.2220
#                                                   Adj R-squared   =     0.1995
#                                                   Within R-sq.    =     0.0019
# Number of clusters (token)   =         39         Root MSE        =     0.1927
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# treasury_e~e |  -.0183845   .0138627    -1.33   0.193     -.046448     .009679
#        _cons |  -.0315955   .0075399    -4.19   0.000    -.0468593   -.0163317
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 4 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,640
# Absorbing 2 HDFE groups                           F(   1,     38) =       3.95
# Statistics robust to heteroskedasticity           Prob > F        =     0.0542
#                                                   R-squared       =     0.2218
#                                                   Adj R-squared   =     0.1993
#                                                   Within R-sq.    =     0.0016
# Number of clusters (token)   =         39         Root MSE        =     0.1927
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# voting_mec~e |   .0365937   .0184192     1.99   0.054     -.000694    .0738814
#        _cons |  -.0434246    .000921   -47.15   0.000    -.0452889   -.0415602
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 4 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,640
# Absorbing 2 HDFE groups                           F(   1,     38) =       3.95
# Statistics robust to heteroskedasticity           Prob > F        =     0.0542
#                                                   R-squared       =     0.2215
#                                                   Adj R-squared   =     0.1990
#                                                   Within R-sq.    =     0.0013
# Number of clusters (token)   =         39         Root MSE        =     0.1927
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# protocol_s~y |  -.0214583    .010803    -1.99   0.054    -.0433278    .0004113
#        _cons |  -.0389911   .0013109   -29.74   0.000    -.0416448   -.0363374
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (dropped 4 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,640
# Absorbing 2 HDFE groups                           F(   1,     38) =       0.41
# Statistics robust to heteroskedasticity           Prob > F        =     0.5259
#                                                   R-squared       =     0.2207
#                                                   Adj R-squared   =     0.1982
#                                                   Within R-sq.    =     0.0003
# Number of clusters (token)   =         39         Root MSE        =     0.1928
#
#                                  (Std. err. adjusted for 39 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#          car | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#   tokenomics |  -.0079393    .012402    -0.64   0.526    -.0330458    .0171671
#        _cons |  -.0365941   .0078117    -4.68   0.000     -.052408   -.0207801
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         6           1           5     |
#          dao |        41          41           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
# (output written to tables/reg_car_topic_end.tex)
#
# .
