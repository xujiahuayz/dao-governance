# %% [markdown]
# # Delegation DID

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 19.5
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2025 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user 2-core network, expiring 31 Oct 2026
# Serial number: 501909305069
#   Licensed to: Yichen Luo
#                UCL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
# clear all
# set more off
# set varabbrev off
# version 18
#
# * Paths
# # global PROCESSED_DATA "processed_data"
# global PROCESSED_DATA "/Users/yichenluo/Library/CloudStorage/Dropbox/dao-governance/processed_data"
# global TABLES "tables"
# global FIGURES "figures"
# global OUTPUT "replace varwidth(25) mlabels(, titles) scalars(N r2_a r2_p N_clust) sfmt(%9.0fc %9.3fc %9.3fc %9.0fc) noobs b(3) t(2) starlevels(* 0.10 ** 0.05 *** 0.01) nogaps nocons"
#
# * Constants
# local window = 6
# Out:
# .
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# . version 18
#
# .
# . * Paths
# . # global PROCESSED_DATA "processed_data"
# Unknown #command
# . global PROCESSED_DATA "/Users/yichenluo/Library/CloudStorage/Dropbox/dao-gove
# > rnance/processed_data"
#
# . global TABLES "tables"
#
# . global FIGURES "figures"
#
# . global OUTPUT "replace varwidth(25) mlabels(, titles) scalars(N r2_a r2_p N_c
# > lust) sfmt(%9.0fc %9.3fc %9.3fc %9.0fc) noobs b(3) t(2) starlevels(* 0.10 **
# > 0.05 *** 0.01) nogaps nocons"
#
# .
# . * Constants
# . local window = 6
#
# .

# %%
# %%stata
# import delimited using "$PROCESSED_DATA/reg_did_discussion.csv", clear
#
# egen ct_fe = group(cohort time)
# egen cp_fe = group(cohort space)
#
#
# eststo clear
#
# * Label variables
# label variable non_whale_participation "\${\it Participation}^{Small}_{i,t}\$"
# label variable whale_participation "\${\it Participation}^{Whale}_{i,t}\$"
# label variable treat "\${\it Treat}_{i}\$"
# label variable post "\${\it Post}_{t}\$"
#
# * Small Shareholders Delegation Participation
# reghdfe non_whale_participation c.treat##c.post, ///
#     absorb(ct_fe cp_fe) vce(cluster space)
# estadd local fe_token "Y"
# estadd local fe_time "Y"
# eststo non_whale_participation
#
# * Whale Delegation Participation
# reghdfe whale_participation c.treat##c.post, ///
#     absorb(ct_fe cp_fe) vce(cluster space)
# estadd local fe_token "Y"
# estadd local fe_time "Y"
# eststo whale_participation
#
# * Export LaTeX table
# esttab                                                      ///
#     non_whale_participation whale_participation             ///
#     using "$TABLES/reg_did_discussion.tex", replace         ///
#     se star(* 0.10 ** 0.05 *** 0.01) nogaps nocon           ///
#     b(%9.3f) se(%9.2f)                                      ///
#     label nogaps booktabs nonotes noomitted eqlabels(none)  ///
#     mtitles("\${\it Participation}^{Small}_{i,t}\$"         ///
#     "\${\it Participation}^{Whale}_{i,t}\$")                ///
#     substitute("\_" "_")                                    ///
#     stats(fe_token fe_time N r2_a,                          ///
#         fmt(0 0 %9.0fc %9.3f)                               ///
#          labels("Cohort-DAO FE" "Cohort-Year FE" "Observations" "Adjusted R²"))
# Out:
# . import delimited using "$PROCESSED_DATA/reg_did_discussion.csv", clear
# (encoding automatically selected: ISO-8859-1)
# (9 vars, 2,184 obs)
#
# .
# . egen ct_fe = group(cohort time)
#
# . egen cp_fe = group(cohort space)
#
# .
# .
# . eststo clear
#
# .
# . * Label variables
# . label variable non_whale_participation "\${\it Participation}^{Small}_{i,t}\$
# > "
#
# . label variable whale_participation "\${\it Participation}^{Whale}_{i,t}\$"
#
# . label variable treat "\${\it Treat}_{i}\$"
#
# . label variable post "\${\it Post}_{t}\$"
#
# .
# . * Small Shareholders Delegation Participation
# . reghdfe non_whale_participation c.treat##c.post, ///
# >     absorb(ct_fe cp_fe) vce(cluster space)
# (dropped 792 singleton observations)
# (MWFE estimator converged in 11 iterations)
# note: treat is probably collinear with the fixed effects (all partialled-out va
# > lues are close to zero; tol = 1.0e-09)
# note: post is probably collinear with the fixed effects (all partialled-out val
# > ues are close to zero; tol = 1.0e-09)
#
# HDFE Linear regression                            Number of obs   =      1,328
# Absorbing 2 HDFE groups                           F(   1,     26) =       4.21
# Statistics robust to heteroskedasticity           Prob > F        =     0.0503
#                                                   R-squared       =     0.8248
#                                                   Adj R-squared   =     0.6650
#                                                   Within R-sq.    =     0.0086
# Number of clusters (space)   =         27         Root MSE        =     0.0173
#
#                                  (Std. err. adjusted for 27 clusters in space)
# ------------------------------------------------------------------------------
#              |               Robust
# non_whale_~n | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#        treat |          0  (omitted)
#         post |          0  (omitted)
#              |
#      c.treat#|
#       c.post |  -.0053302   .0025963    -2.05   0.050     -.010667    6.48e-06
#              |
#        _cons |   .0189165   .0004829    39.17   0.000     .0179239    .0199091
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        ct_fe |       487           1         486     |
#        cp_fe |       147         147           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# . estadd local fe_token "Y"
#
# added macro:
#            e(fe_token) : "Y"
#
# . estadd local fe_time "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# . eststo non_whale_participation
#
# .
# . * Whale Delegation Participation
# . reghdfe whale_participation c.treat##c.post, ///
# >     absorb(ct_fe cp_fe) vce(cluster space)
# (dropped 741 singleton observations)
# (MWFE estimator converged in 11 iterations)
# note: treat is probably collinear with the fixed effects (all partialled-out va
# > lues are close to zero; tol = 1.0e-09)
# note: post is probably collinear with the fixed effects (all partialled-out val
# > ues are close to zero; tol = 1.0e-09)
#
# HDFE Linear regression                            Number of obs   =      1,194
# Absorbing 2 HDFE groups                           F(   1,     24) =       0.47
# Statistics robust to heteroskedasticity           Prob > F        =     0.4974
#                                                   R-squared       =     0.8443
#                                                   Adj R-squared   =     0.7009
#                                                   Within R-sq.    =     0.0026
# Number of clusters (space)   =         25         Root MSE        =     0.1478
#
#                                  (Std. err. adjusted for 25 clusters in space)
# ------------------------------------------------------------------------------
#              |               Robust
# whale_part~n | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#        treat |          0  (omitted)
#         post |          0  (omitted)
#              |
#      c.treat#|
#       c.post |   .0256313   .0371954     0.69   0.497    -.0511362    .1023989
#              |
#        _cons |   .2864669   .0066977    42.77   0.000     .2726436    .3002902
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        ct_fe |       436           1         435     |
#        cp_fe |       137         137           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# . estadd local fe_token "Y"
#
# added macro:
#            e(fe_token) : "Y"
#
# . estadd local fe_time "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# . eststo whale_participation
#
# .
# . * Export LaTeX table
# . esttab                                                      ///
# >     non_whale_participation whale_participation             ///
# >     using "$TABLES/reg_did_discussion.tex", replace         ///
# >     se star(* 0.10 ** 0.05 *** 0.01) nogaps nocon           ///
# >     b(%9.3f) se(%9.2f)                                      ///
# >     label nogaps booktabs nonotes noomitted eqlabels(none)  ///
# >     mtitles("\${\it Participation}^{Small}_{i,t}\$"         ///
# >     "\${\it Participation}^{Whale}_{i,t}\$")                ///
# >     substitute("\_" "_")                                    ///
# >     stats(fe_token fe_time N r2_a,                          ///
# >         fmt(0 0 %9.0fc %9.3f)                               ///
# >          labels("Cohort-DAO FE" "Cohort-Year FE" "Observations" "Adjusted R²"
# > ))
# (output written to tables/reg_did_discussion.tex)
#
# .

# %%
# %%stata
# forval i = `window'(-1)1 {
#     gen treat__`i' = treat * (event_time == -`i')
# }
# forval i = 0(1)`window' {
#     gen treat_`i' = treat * (event_time == `i')
# }
# drop treat__1
# eststo: reghdfe non_whale_participation c.treat_*, ///
#     absorb(ct_fe cp_fe) vce(cluster space)
# Out:
# . forval i = `window'(-1)1 {
#   2.     gen treat__`i' = treat * (event_time == -`i')
#   3. }
#
# . forval i = 0(1)`window' {
#   2.     gen treat_`i' = treat * (event_time == `i')
#   3. }
#
# . drop treat__1
#
# . eststo: reghdfe non_whale_participation c.treat_*, ///
# >     absorb(ct_fe cp_fe) vce(cluster space)
# (dropped 792 singleton observations)
# (MWFE estimator converged in 10 iterations)
#
# HDFE Linear regression                            Number of obs   =      1,328
# Absorbing 2 HDFE groups                           F(  12,     26) =       3.36
# Statistics robust to heteroskedasticity           Prob > F        =     0.0047
#                                                   R-squared       =     0.8327
#                                                   Adj R-squared   =     0.6749
#                                                   Within R-sq.    =     0.0529
# Number of clusters (space)   =         27         Root MSE        =     0.0170
#
#                                  (Std. err. adjusted for 27 clusters in space)
# ------------------------------------------------------------------------------
#              |               Robust
# non_whale_~n | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     treat__6 |   .0112644    .008106     1.39   0.176    -.0053978    .0279266
#     treat__5 |  -.0012102   .0044313    -0.27   0.787    -.0103188    .0078984
#     treat__4 |  -.0069297   .0140051    -0.49   0.625    -.0357177    .0218582
#     treat__3 |   .0006422   .0029657     0.22   0.830    -.0054539    .0067383
#     treat__2 |  -.0122512   .0093107    -1.32   0.200    -.0313896    .0068871
#      treat_0 |  -.0003687   .0037369    -0.10   0.922      -.00805    .0073127
#      treat_1 |  -.0022891    .002379    -0.96   0.345    -.0071792    .0026009
#      treat_2 |   -.008171   .0058755    -1.39   0.176    -.0202483    .0039063
#      treat_3 |  -.0075153   .0049723    -1.51   0.143    -.0177361    .0027055
#      treat_4 |  -.0094888   .0035357    -2.68   0.012    -.0167565   -.0022212
#      treat_5 |  -.0087881   .0042037    -2.09   0.046    -.0174288   -.0001473
#      treat_6 |  -.0136353   .0085705    -1.59   0.124    -.0312522    .0039816
#        _cons |   .0194553   .0013164    14.78   0.000     .0167493    .0221612
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        ct_fe |       487           1         486     |
#        cp_fe |       147         147           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
# (est3 stored)
#
# .

# %%
# %%stata
# ****************************************************
# * Extract coefficient vectors
# ****************************************************
# matrix b = e(b)
# matrix V = e(V)
#
# ****************************************************
# * Create event-time dataset
# ****************************************************
#
# preserve
# clear
# set obs `=`window'*2 + 1'
#
# gen event_time = -`window' + _n - 1
# gen beta = .
# gen se   = .
#
# ****************************************************
# * Fill coefficients except base period (-1)
# ****************************************************
#
# forvalues t = -`window'/`window' {
#
#     if `t' == -1 {
#         replace beta = 0 if event_time == `t'
#         replace se   = 0 if event_time == `t'
#     }
#     else {
#
#         if `t' < 0 {
#             local varname = "treat__" + string(abs(`t'))
#         }
#         else {
#             local varname = "treat_" + string(`t')
#         }
#
#         replace beta = b[1,"`varname'"]                 if event_time == `t'
#         replace se   = sqrt(V["`varname'","`varname'"]) if event_time == `t'
#     }
# }
#
#
#
# ****************************************************
# * 90% CI
# ****************************************************
#
# gen ub = beta + invttail(e(df_r), 0.1)*se
# gen lb = beta - invttail(e(df_r), 0.1)*se
#
# ****************************************************
# * EVENT STUDY PLOT
# ****************************************************
#
# twoway ///
#     rarea ub lb event_time, ///
#         color(navy%50) ///
#         lcolor(navy) lwidth(thin)  ///
#     || ///
#     line beta event_time, ///
#         lcolor(navy) lwidth(thin) ///
#     || ///
#     scatter beta event_time, ///
#         mcolor(navy) msymbol(O) msize(small) ///
#     ///
#     xline(0, lcolor(black) lpattern(dash)) ///
#     yline(0, lcolor(black) lpattern(dash)) ///
#     ///
#     xtitle("Proposal Count Since Enabling Discussion") ///
#     ytitle("Average Effects") ///
#     ///
#     xlabel(-`window'(1)`window', grid gmin gmax) ///
#     yscale(range(-0.01 0.02)) ///
#     ylabel(-0.01(0.01)0.02) ///
#     legend(off) ///
#     ///
#     plotregion(color(white)) ///
#     graphregion(color(white))
#
# graph export "$FIGURES/dynamic_discussion.pdf", replace
#
# restore
# Out:
# . ****************************************************
# . * Extract coefficient vectors
# . ****************************************************
# . matrix b = e(b)
#
# . matrix V = e(V)
#
# .
# . ****************************************************
# . * Create event-time dataset
# . ****************************************************
# .
# . preserve
#
# . clear
#
# . set obs `=`window'*2 + 1'
# Number of observations (_N) was 0, now 13.
#
# .
# . gen event_time = -`window' + _n - 1
#
# . gen beta = .
# (13 missing values generated)
#
# . gen se   = .
# (13 missing values generated)
#
# .
# . ****************************************************
# . * Fill coefficients except base period (-1)
# . ****************************************************
# .
# . forvalues t = -`window'/`window' {
#   2.
# .     if `t' == -1 {
#   3.         replace beta = 0 if event_time == `t'
#   4.         replace se   = 0 if event_time == `t'
#   5.     }
#   6.     else {
#   7.
# .         if `t' < 0 {
#   8.             local varname = "treat__" + string(abs(`t'))
#   9.         }
#  10.         else {
#  11.             local varname = "treat_" + string(`t')
#  12.         }
#  13.
# .         replace beta = b[1,"`varname'"]                 if event_time == `t'
#  14.         replace se   = sqrt(V["`varname'","`varname'"]) if event_time == `
# > t'
#  15.     }
#  16. }
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
# (1 real change made)
#
# .
# .
# .
# . ****************************************************
# . * 90% CI
# . ****************************************************
# .
# . gen ub = beta + invttail(e(df_r), 0.1)*se
#
# . gen lb = beta - invttail(e(df_r), 0.1)*se
#
# .
# . ****************************************************
# . * EVENT STUDY PLOT
# . ****************************************************
# .
# . twoway ///
# >     rarea ub lb event_time, ///
# >         color(navy%50) ///
# >         lcolor(navy) lwidth(thin)  ///
# >     || ///
# >     line beta event_time, ///
# >         lcolor(navy) lwidth(thin) ///
# >     || ///
# >     scatter beta event_time, ///
# >         mcolor(navy) msymbol(O) msize(small) ///
# >     ///
# >     xline(0, lcolor(black) lpattern(dash)) ///
# >     yline(0, lcolor(black) lpattern(dash)) ///
# >     ///
# >     xtitle("Proposal Count Since Enabling Discussion") ///
# >     ytitle("Average Effects") ///
# >     ///
# >     xlabel(-`window'(1)`window', grid gmin gmax) ///
# >     yscale(range(-0.01 0.02)) ///
# >     ylabel(-0.01(0.01)0.02) ///
# >     legend(off) ///
# >     ///
# >     plotregion(color(white)) ///
# >     graphregion(color(white))
#
# .
# . graph export "$FIGURES/dynamic_discussion.pdf", replace
# file figures/dynamic_discussion.pdf saved as PDF format
#
# .
# . restore
#
# .
