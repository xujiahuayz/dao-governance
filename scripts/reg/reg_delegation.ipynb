# %% [markdown]
# # The Determinants of Turnout

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 19.5
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2025 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user 2-core network, expiring 31 Oct 2026
# Serial number: 501909305069
#   Licensed to: Yichen Luo
#                UCL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
# clear all
# set more off
# set varabbrev off
# version 18
#
# * Paths
# global PROCESSED_DATA "/Users/yichenluo/Library/CloudStorage/Dropbox/dao-governance/processed_data"
# global TABLES "tables"
# Out:
# .
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# . version 18
#
# .
# . * Paths
# . global PROCESSED_DATA "/Users/yichenluo/Library/CloudStorage/Dropbox/dao-gove
# > rnance/processed_data"
#
# . global TABLES "tables"
#
# .

# %%
# %%stata
#
# import delimited using "$PROCESSED_DATA/proposals_panel.csv", clear
#
# * Parse date
# gen day = date(date, "YMD")
# format day %td
# gen year = year(day)
#
# * Independent variables
# local complexity multi_choices weighted quorum
# local topic protocol_security treasury_expenditure user_incentive_increase tokenomics voting_mechanism_change
#
#
# * Label variables
# label var weighted "\${\it Weighted}_{i,t}\$"
# label var quorum "\${\it Quorum}_{i,t}\$"
# label var multi_choices "\${\it Multiple Choices}_{i,t}\$"
# label var have_discussion "\${\it Discussion}_{i,t}\$"
# label var non_whale_user      "\${\it User}_{i,t}^{\it Small}\$"
# label var concensus_diff "\${\it \Delta Concensus}_{i,t}\$"
# Out:
# .
# . import delimited using "$PROCESSED_DATA/proposals_panel.csv", clear
# (encoding automatically selected: ISO-8859-1)
# (65 vars, 2,830 obs)
#
# .
# . * Parse date
# . gen day = date(date, "YMD")
#
# . format day %td
#
# . gen year = year(day)
#
# .
# . * Independent variables
# . local complexity multi_choices weighted quorum
#
# . local topic protocol_security treasury_expenditure user_incentive_increase to
# > kenomics voting_mechanism_change
#
# .
# .
# . * Label variables
# . label var weighted "\${\it Weighted}_{i,t}\$"
#
# . label var quorum "\${\it Quorum}_{i,t}\$"
#
# . label var multi_choices "\${\it Multiple Choices}_{i,t}\$"
#
# . label var have_discussion "\${\it Discussion}_{i,t}\$"
#
# . label var non_whale_user      "\${\it User}_{i,t}^{\it Small}\$"
#
# . label var concensus_diff "\${\it \Delta Concensus}_{i,t}\$"
#
# .

# %% [markdown]
# ## Proposal Characteristics

# %%
# %%stata
#
# ******************************************************
# * PANEL REGRESSIONS
# ******************************************************
#
# eststo clear
#
#     * Run baseline regression
#     reghdfe non_whale_from_delegation_rate `complexity' have_discussion , absorb(year categories)
#     eststo baseline
#     estadd local fe_proposal  "Y"
#     estadd local fe_time  "Y"
#
#
#     * Run regression with discussion characteristics
#     reghdfe non_whale_from_delegation_rate `complexity' concensus_diff, absorb(year categories)
#     eststo discussion
#     estadd local fe_proposal  "Y"
#     estadd local fe_time  "Y"
#
#
#     * Run regression with user characteristics
#     reghdfe non_whale_from_delegation_rate `complexity' have_discussion non_whale_user, absorb(year categories)
#     eststo user
#     estadd local fe_proposal  "Y"
#     estadd local fe_time  "Y"
#
# * Export LaTeX table
# esttab                                                           ///
#     baseline discussion user                                     ///
#     using "$TABLES/reg_delegation.tex", replace                  ///
#     se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon nonumbers ///
#     nonotes booktabs nomtitles                                   ///
#     b(%9.3f) se(%9.2f)                                           ///
#     order(have_discussion concensus_diff non_whale_user multi_choices weighted quorum) ///
#     mgroups("\${\it Delegation}^{Small}_{i,t}\$",                ///
#             span                                                 ///
#             pattern(1 0 0)                                       ///
#             prefix(\multicolumn{@span}{c}{)                      ///
#             suffix(})                                            ///
#             erepeat(\cmidrule(lr){@span}) )                      ///
#     posthead(\cmidrule(lr){2-4} & \multicolumn{1}{c}{Full} & \multicolumn{1}{c}{Discussion \$\geq\$ 2} & \multicolumn{1}{c}{Have Dapp} \\ \cmidrule(lr){2-4} & \multicolumn{1}{c}{(1)} & \multicolumn{1}{c}{(2)} & \multicolumn{1}{c}{(3)} \\ \midrule) ///
#             substitute("\_" "_")                                ///
#     stats(fe_proposal fe_time N r2_a,                            ///
#         fmt(0 0 %9.0fc %9.3f)                                    ///
#          labels("Category FE" "Year FE" "Observations" "Adjusted R²"))
# Out:
# .
# . ******************************************************
# . * PANEL REGRESSIONS
# . ******************************************************
# .
# . eststo clear
#
# .
# .     * Run baseline regression
# .     reghdfe non_whale_from_delegation_rate `complexity' have_discussion , abs
# > orb(year categories)
# (MWFE estimator converged in 5 iterations)
#
# HDFE Linear regression                            Number of obs   =        682
# Absorbing 2 HDFE groups                           F(   4,    670) =       6.33
#                                                   Prob > F        =     0.0001
#                                                   R-squared       =     0.8009
#                                                   Adj R-squared   =     0.7976
#                                                   Within R-sq.    =     0.0364
#                                                   Root MSE        =     0.0096
#
# ------------------------------------------------------------------------------
# n~from_del~e | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# multi_choi~s |   .0009553   .0012165     0.79   0.433    -.0014333     .003344
#     weighted |   .0014841   .0010298     1.44   0.150    -.0005379     .003506
#       quorum |   .0028959    .002194     1.32   0.187    -.0014121     .007204
# have_di~sion |   .0059726   .0013971     4.28   0.000     .0032294    .0087157
#        _cons |   .0275347   .0020853    13.20   0.000     .0234402    .0316293
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         5           0           5     |
#   categories |         4           1           3     |
# -----------------------------------------------------+
#
# .     eststo baseline
#
# .     estadd local fe_proposal  "Y"
#
# added macro:
#         e(fe_proposal) : "Y"
#
# .     estadd local fe_time  "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# .
# .
# .     * Run regression with discussion characteristics
# .     reghdfe non_whale_from_delegation_rate `complexity' concensus_diff, absor
# > b(year categories)
# (MWFE estimator converged in 4 iterations)
#
# HDFE Linear regression                            Number of obs   =        277
# Absorbing 2 HDFE groups                           F(   4,    266) =       0.81
#                                                   Prob > F        =     0.5189
#                                                   R-squared       =     0.6645
#                                                   Adj R-squared   =     0.6519
#                                                   Within R-sq.    =     0.0121
#                                                   Root MSE        =     0.0117
#
# ------------------------------------------------------------------------------
# n~from_del~e | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# multi_choi~s |   .0007534   .0027343     0.28   0.783    -.0046302    .0061369
#     weighted |  -.0004983   .0020129    -0.25   0.805    -.0044616     .003465
#       quorum |   .0014543   .0059314     0.25   0.806    -.0102242    .0131329
# concensus_~f |   .0038829   .0021963     1.77   0.078    -.0004415    .0082073
#        _cons |   .0383266   .0059766     6.41   0.000     .0265591    .0500941
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         5           0           5     |
#   categories |         3           1           2     |
# -----------------------------------------------------+
#
# .     eststo discussion
#
# .     estadd local fe_proposal  "Y"
#
# added macro:
#         e(fe_proposal) : "Y"
#
# .     estadd local fe_time  "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# .
# .
# .     * Run regression with user characteristics
# .     reghdfe non_whale_from_delegation_rate `complexity' have_discussion non_w
# > hale_user, absorb(year categories)
# (MWFE estimator converged in 5 iterations)
#
# HDFE Linear regression                            Number of obs   =        673
# Absorbing 2 HDFE groups                           F(   5,    660) =       6.92
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.7998
#                                                   Adj R-squared   =     0.7961
#                                                   Within R-sq.    =     0.0498
#                                                   Root MSE        =     0.0096
#
# ------------------------------------------------------------------------------
# n~from_del~e | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# multi_choi~s |   .0013326   .0012222     1.09   0.276    -.0010672    .0037325
#     weighted |   .0016495    .001035     1.59   0.111    -.0003827    .0036817
#       quorum |   .0049371   .0023175     2.13   0.034     .0003865    .0094877
# have_di~sion |   .0070485   .0014415     4.89   0.000      .004218    .0098791
# non_whale_~r |   .0096194    .003225     2.98   0.003     .0032869    .0159519
#        _cons |   .0185558   .0037313     4.97   0.000     .0112292    .0258825
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#         year |         5           0           5     |
#   categories |         4           1           3     |
# -----------------------------------------------------+
#
# .     eststo user
#
# .     estadd local fe_proposal  "Y"
#
# added macro:
#         e(fe_proposal) : "Y"
#
# .     estadd local fe_time  "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# .
# . * Export LaTeX table
# . esttab                                                           ///
# >     baseline discussion user                                     ///
# >     using "$TABLES/reg_delegation.tex", replace                  ///
# >     se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon nonumbers ///
# >     nonotes booktabs nomtitles                                   ///
# >     b(%9.3f) se(%9.2f)                                           ///
# >     order(have_discussion concensus_diff non_whale_user multi_choices weighte
# > d quorum) ///
# >     mgroups("\${\it Delegation}^{Small}_{i,t}\$",                ///
# >             span                                                 ///
# >             pattern(1 0 0)                                       ///
# >             prefix(\multicolumn{@span}{c}{)                      ///
# >             suffix(})                                            ///
# >             erepeat(\cmidrule(lr){@span}) )                      ///
# >     posthead(\cmidrule(lr){2-4} & \multicolumn{1}{c}{Full} & \multicolumn{1}{
# > c}{Discussion \$\geq\$ 2} & \multicolumn{1}{c}{Have Dapp} \\ \cmidrule(lr){2-
# > 4} & \multicolumn{1}{c}{(1)} & \multicolumn{1}{c}{(2)} & \multicolumn{1}{c}{(
# > 3)} \\ \midrule) ///
# >             substitute("\_" "_")                                ///
# >     stats(fe_proposal fe_time N r2_a,                            ///
# >         fmt(0 0 %9.0fc %9.3f)                                    ///
# >          labels("Category FE" "Year FE" "Observations" "Adjusted R²"))
# (output written to tables/reg_delegation.tex)
#
# .
