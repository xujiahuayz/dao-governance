# %% [markdown]
# # T-Test Table

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')

# %%
# %%stata
# clear all
# set more off
# set varabbrev off
#
# global PROCESSED_DATA "processed_data"
# global TABLES "tables"
#
# ****************************************************
# * Import & sample restriction
# ****************************************************
# import delimited "$PROCESSED_DATA/proposals_panel.csv", clear varn(1) case(lower)
#
# ****************************************************
# * Mean comparison & t-test for multiple variables
# * All variables share the same columns
# ****************************************************
#
# * Put all variables you want here:
# local vars protocol_security treasury_expenditure user_incentive_increase tokenomics voting_mechanism_change concensus professionalism objectiveness data_intensity hhi_post_number
#
# * Single estpost with varlist -> shared columns in esttab
# estpost ttest `vars', by(infrastructure)
#
# * Export (shared columns; one row per variable)
# esttab using "$TABLES/sum_infrastructure.tex", ///
#     cells("mu_1(fmt(3)) mu_2(fmt(3)) b(fmt(3)) t(fmt(2)star)") ///
#     wide unstack ///
#     nonumber ///
#     star(* 0.1 ** 0.05 *** 0.01) ///
#     label noobs nonumber nomtitles booktabs replace ///
#     substitute("\_" "_") ///
#     collabels("Without Infrastructure" "With Infrastructure" "Without - With" "t-stat") ///
#     varlabels( ///
#     protocol_security "\${\it Protocol Security}_{i}\$" ///
#     treasury_expenditure "\${\it Treasury Expenditure}_{i}\$" ///
#     user_incentive_increase "\${\it User Incentive Increase}_{i}\$" ///
#     tokenomics "\${\it Tokenomics}_{i}\$" ///
#     voting_mechanism_change "\${\it Voting Mechanism Change}_{i}\$" ///
#     concensus "\${\it Concensus}_{i}\$" ///
#     professionalism "\${\it Professionalism}_{i}\$" ///
#     objectiveness "\${\it Objectiveness}_{i}\$" ///
#     data_intensity "\${\it Data Intensity}_{i}\$" ///
#     hhi_post_number "\${\it HHI}_{i}^{\# Post}\$" ///
#     )
# Out:
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# .
# . global PROCESSED_DATA "processed_data"
#
# . global TABLES "tables"
#
# .
# . ****************************************************
# . * Import & sample restriction
# . ****************************************************
# . import delimited "$PROCESSED_DATA/proposals_panel.csv", clear varn(1) case(lo
# > wer)
# (encoding automatically selected: ISO-8859-1)
# (57 vars, 2,841 obs)
#
# .
# . ****************************************************
# . * Mean comparison & t-test for multiple variables
# . * All variables share the same columns
# . ****************************************************
# .
# . * Put all variables you want here:
# . local vars protocol_security treasury_expenditure user_incentive_increase tok
# > enomics voting_mechanism_change concensus professionalism objectiveness data_
# > intensity hhi_post_number
#
# .
# . * Single estpost with varlist -> shared columns in esttab
# . estpost ttest `vars', by(infrastructure)
#
#              |      e(b)   e(count)      e(se)       e(t)    e(df_t)
# -------------+-------------------------------------------------------
# protocol_s~y | -.0124656       2470   .0168157   -.741308       2468
# treasury_e~e |  .0442926       2470   .0263611   1.680223       2468
# user_incen~e | -.0097475       2470   .0242485  -.4019838       2468
#   tokenomics |  .0383975       2470   .0254529   1.508572       2468
# voting_mec~e |  .0159515       2470   .0111489   1.430774       2468
#    concensus | -.0542916        751   .0437574  -1.240741        749
# profession~m |   -.02051        751   .0115048  -1.782728        749
# objectiven~s | -.0294005        751   .0320754  -.9166055        749
# data_inten~y |  .0968869        751   .0425653   2.276195        749
# hhi_post_n~r |  -.166062        751   .0508703  -3.264422        749
#
#              |    e(p_l)       e(p)     e(p_u)     e(N_1)    e(mu_1)
# -------------+-------------------------------------------------------
# protocol_s~y |  .2292886   .4585772   .7707114        424   .1014151
# treasury_e~e |  .9534797   .0930406   .0465203        424   .6132075
# user_incen~e |  .3438654   .6877308   .6561346        424   .2830189
#   tokenomics |  .9342319   .1315362   .0657681        424   .6816038
# voting_mec~e |  .9236893   .1526215   .0763107        424   .0589623
#    concensus |   .107545     .21509    .892455         96   .3415933
# profession~m |  .0375178   .0750356   .9624822         96   .9454822
# objectiven~s |  .1798222   .3596444   .8201778         96    .669498
# data_inten~y |  .9884421   .0231158   .0115579         96   .3906559
# hhi_post_n~r |  .0005734   .0011467   .9994266         96   .2822231
#
#              |    e(N_2)    e(mu_2)
# -------------+----------------------
# protocol_s~y |      2046   .1138807
# treasury_e~e |      2046    .568915
# user_incen~e |      2046   .2927664
#   tokenomics |      2046   .6432063
# voting_mec~e |      2046   .0430108
#    concensus |       655   .3958849
# profession~m |       655   .9659922
# objectiven~s |       655   .6988985
# data_inten~y |       655    .293769
# hhi_post_n~r |       655    .448285
#
# .
# . * Export (shared columns; one row per variable)
# . esttab using "$TABLES/sum_infrastructure.tex", ///
# >     cells("mu_1(fmt(3)) mu_2(fmt(3)) b(fmt(3)) t(fmt(2)star)") ///
# >     wide unstack ///
# >     nonumber ///
# >     star(* 0.1 ** 0.05 *** 0.01) ///
# >     label noobs nonumber nomtitles booktabs replace ///
# >     substitute("\_" "_") ///
# >     collabels("Without Infrastructure" "With Infrastructure" "Without - With"
# >  "t-stat") ///
# >     varlabels( ///
# >     protocol_security "\${\it Protocol Security}_{i}\$" ///
# >     treasury_expenditure "\${\it Treasury Expenditure}_{i}\$" ///
# >     user_incentive_increase "\${\it User Incentive Increase}_{i}\$" ///
# >     tokenomics "\${\it Tokenomics}_{i}\$" ///
# >     voting_mechanism_change "\${\it Voting Mechanism Change}_{i}\$" ///
# >     concensus "\${\it Concensus}_{i}\$" ///
# >     professionalism "\${\it Professionalism}_{i}\$" ///
# >     objectiveness "\${\it Objectiveness}_{i}\$" ///
# >     data_intensity "\${\it Data Intensity}_{i}\$" ///
# >     hhi_post_number "\${\it HHI}_{i}^{\# Post}\$" ///
# >     )
# (output written to tables/sum_infrastructure.tex)
#
# .
