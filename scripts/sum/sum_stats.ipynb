# %% [markdown]
# # T-Test Table

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      StataNow 19.5
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2025 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-782-8272        https://www.stata.com
#                                    979-696-4600        service@stata.com
#
# Stata license: Unlimited-user 2-core network, expiring 31 Oct 2026
# Serial number: 501909305069
#   Licensed to: Yichen Luo
#                UCL
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
# clear all
# set more off
# set varabbrev off
#
# global PROCESSED_DATA "/Users/yichenluo/Library/CloudStorage/Dropbox/dao-governance/processed_data"
# global TABLES "tables"
#
# import delimited using "$PROCESSED_DATA/proposals_panel.csv", clear
#
# * Dependent variables
# local cars car_created car_end
# local participation non_whale_participation
# local user non_whale_user
# local wins non_whale_victory_vn
# local proposal_char weighted multi_choices quorum delegation have_discussion
# local discussion_char concensus_diff
# local topic_char protocol_security treasury_expenditure user_incentive_increase tokenomics voting_mechanism_change
#
# * Label variables
# label var car_created "\${\it CAR}[-5,5]_{i}^{\it created}\$"
# label var car_end "\${\it CAR}[-5,5]_{i}^{\it end}\$"
# label var non_whale_victory_vn "\${\it Small Win}_{i}\$"
# label var non_whale_participation "\${\it Participation}^{Small}_{i}\$"
# label var non_whale_user "\${\it User}_{i}^{\it Small}\$"
# label var weighted "\${\it Weighted}_{i}\$"
# label var multi_choices "\${\it Multiple Choices}_{i}\$"
# label var quorum "\${\it Quorum}_{i}\$"
# label var delegation "\${\it Delegation}_{i}\$"
# label var have_discussion "\${\it Discussion}_{i}\$"
# label var concensus_diff "\${\it \Delta Concensus}_{i}\$"
# label var user_incentive_increase "\${\it User Incentive Increase}_{i}\$"
# label var treasury_expenditure "\${\it Treasury Expenditure}_{i}\$"
# label var voting_mechanism_change "\${\it Voting Mechanism Change}_{i}\$"
# label var protocol_security "\${\it Protocol Security}_{i}\$"
# label var tokenomics "\${\it Tokenomics}_{i}\$"
# Out:
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# .
# . global PROCESSED_DATA "/Users/yichenluo/Library/CloudStorage/Dropbox/dao-gove
# > rnance/processed_data"
#
# . global TABLES "tables"
#
# .
# . import delimited using "$PROCESSED_DATA/proposals_panel.csv", clear
# (encoding automatically selected: ISO-8859-1)
# (65 vars, 2,830 obs)
#
# .
# . * Dependent variables
# . local cars car_created car_end
#
# . local participation non_whale_participation
#
# . local user non_whale_user
#
# . local wins non_whale_victory_vn
#
# . local proposal_char weighted multi_choices quorum delegation have_discussion
#
# . local discussion_char concensus_diff
#
# . local topic_char protocol_security treasury_expenditure user_incentive_increa
# > se tokenomics voting_mechanism_change
#
# .
# . * Label variables
# . label var car_created "\${\it CAR}[-5,5]_{i}^{\it created}\$"
#
# . label var car_end "\${\it CAR}[-5,5]_{i}^{\it end}\$"
#
# . label var non_whale_victory_vn "\${\it Small Win}_{i}\$"
#
# . label var non_whale_participation "\${\it Participation}^{Small}_{i}\$"
#
# . label var non_whale_user "\${\it User}_{i}^{\it Small}\$"
#
# . label var weighted "\${\it Weighted}_{i}\$"
#
# . label var multi_choices "\${\it Multiple Choices}_{i}\$"
#
# . label var quorum "\${\it Quorum}_{i}\$"
#
# . label var delegation "\${\it Delegation}_{i}\$"
#
# . label var have_discussion "\${\it Discussion}_{i}\$"
#
# . label var concensus_diff "\${\it \Delta Concensus}_{i}\$"
#
# . label var user_incentive_increase "\${\it User Incentive Increase}_{i}\$"
#
# . label var treasury_expenditure "\${\it Treasury Expenditure}_{i}\$"
#
# . label var voting_mechanism_change "\${\it Voting Mechanism Change}_{i}\$"
#
# . label var protocol_security "\${\it Protocol Security}_{i}\$"
#
# . label var tokenomics "\${\it Tokenomics}_{i}\$"
#
# .

# %%
# %%stata
#
# ******************************************************
# * SUMMARY STATISTICS
# ******************************************************
# * Summarize all key variables
# summarize `cars' `participation' `wins' `proposal_char' `discussion_char' `user' `topic_char', detail
#
# * Export a nice LaTeX summary table with mean, SD, p10, median, p90
# estpost summarize `cars' `participation' `wins' `proposal_char' `discussion_char' `user' `topic_char', detail
# esttab using "$TABLES/summary_stats.tex", replace ///
#     cells("count(fmt(0)) mean(fmt(3)) sd(fmt(3)) min(fmt(3)) p25(fmt(3)) p50(fmt(3)) p75(fmt(3)) max(fmt(3))") ///
#     collabels("Number of Obs." "Mean" "Std. Dev." "Min" "P25" "P50" "P75" "Max") ///
#     nonumber nomtitles noobs label ///
#     alignment(D{.}{.}{-1}) booktabs ///
#     compress nofloat nostar ///
#     substitute("\_" "_")                     ///
#     title("Summary Statistics of Variables") ///
#     prehead("\begin{tabular}{l*{9}{c}}\toprule") ///
#     posthead("\hline") ///
#     postfoot("\bottomrule\end{tabular}")
# Out:
# .
# . ******************************************************
# . * SUMMARY STATISTICS
# . ******************************************************
# . * Summarize all key variables
# . summarize `cars' `participation' `wins' `proposal_char' `discussion_char' `us
# > er' `topic_char', detail
#
#              ${\it CAR}[-5,5]_{i}^{\it created}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%    -.5506855      -1.076359
#  5%    -.3886827       -.787218
# 10%    -.2914971      -.6827748       Obs               1,593
# 25%    -.1241135      -.6806505       Sum of wgt.       1,593
#
# 50%     -.021734                      Mean          -.0183644
#                         Largest       Std. dev.      .2685018
# 75%     .0630045       1.305479
# 90%     .2163358       1.463126       Variance       .0720932
# 95%      .415639        1.48296       Skewness       6.972902
# 99%     .6221527       5.858808       Kurtosis       148.0914
#
#                ${\it CAR}[-5,5]_{i}^{\it end}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%    -.6044713      -1.000393
#  5%    -.4219742      -.8783544
# 10%    -.3078582      -.8783544       Obs               1,658
# 25%    -.1397889      -.8783544       Sum of wgt.       1,658
#
# 50%    -.0294226                      Mean          -.0400436
#                         Largest       Std. dev.      .2163957
# 75%     .0631476       .8610196
# 90%     .2047631       .9602333       Variance       .0468271
# 95%     .2875741       1.089469       Skewness       .1165242
# 99%     .5502529       1.140595       Kurtosis        5.60718
#
#               ${\it Participation}^{Small}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%     .0002275              0       Obs               2,667
# 25%     .0023566              0       Sum of wgt.       2,667
#
# 50%     .0105513                      Mean           .0317196
#                         Largest       Std. dev.      .0449758
# 75%     .0518732       .2484313
# 90%     .0852713       .2484313       Variance       .0020228
# 95%     .1292439       .2484313       Skewness       2.201079
# 99%     .2484313       .2484313       Kurtosis       8.810736
#
#                     ${\it Small Win}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,669
# 25%            0              0       Sum of wgt.       2,669
#
# 50%            0                      Mean           .0678157
#                         Largest       Std. dev.      .2514764
# 75%            0              1
# 90%            0              1       Variance       .0632404
# 95%            1              1       Skewness        3.43782
# 99%            1              1       Kurtosis       12.81861
#
#                     ${\it Weighted}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .1339223
#                         Largest       Std. dev.       .340629
# 75%            0              1
# 90%            1              1       Variance       .1160281
# 95%            1              1       Skewness       2.149802
# 99%            1              1       Kurtosis       5.621649
#
#                 ${\it Multiple Choices}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .4226148
#                         Largest       Std. dev.      .4940625
# 75%            1              1
# 90%            1              1       Variance       .2440978
# 95%            1              1       Skewness       .3133159
# 99%            1              1       Kurtosis       1.098167
#
#                      ${\it Quorum}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .2992933
#                         Largest       Std. dev.      .4580294
# 75%            1              1
# 90%            1              1       Variance       .2097909
# 95%            1              1       Skewness       .8765471
# 99%            1              1       Kurtosis       1.768335
#
#                    ${\it Delegation}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .2636042
#                         Largest       Std. dev.       .440665
# 75%            1              1
# 90%            1              1       Variance       .1941857
# 95%            1              1       Skewness       1.073094
# 99%            1              1       Kurtosis       2.151531
#
#                    ${\it Discussion}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean            .395053
#                         Largest       Std. dev.      .4889485
# 75%            1              1
# 90%            1              1       Variance       .2390706
# 95%            1              1       Skewness       .4293522
# 99%            1              1       Kurtosis       1.184343
#
#                 ${\it \Delta Concensus}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%    -.7685081      -.9866134
#  5%    -.3299616      -.9598994
# 10%    -.1532581      -.9474552       Obs                 581
# 25%    -.0012337      -.7875909       Sum of wgt.         581
#
# 50%     .0379507                      Mean           .1357869
#                         Largest       Std. dev.      .3245954
# 75%     .2910298       .9760368
# 90%     .6115506       .9860474       Variance       .1053622
# 95%      .828934       .9861484       Skewness       .2865379
# 99%      .954693       .9953478       Kurtosis       4.197167
#
#                 ${\it User}_{i}^{\it Small}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,439
# 25%     .0218978              0       Sum of wgt.       2,439
#
# 50%           .8                      Mean           .5715484
#                         Largest       Std. dev.      .4238602
# 75%     .9634146              1
# 90%            1              1       Variance       .1796575
# 95%            1              1       Skewness      -.3714786
# 99%            1              1       Kurtosis        1.33276
#
#                 ${\it Protocol Security}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .1028269
#                         Largest       Std. dev.      .3037863
# 75%            0              1
# 90%            1              1       Variance       .0922861
# 95%            1              1       Skewness       2.615282
# 99%            1              1       Kurtosis       7.839698
#
#               ${\it Treasury Expenditure}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            1                      Mean           .5731449
#                         Largest       Std. dev.      .4947083
# 75%            1              1
# 90%            1              1       Variance       .2447363
# 95%            1              1       Skewness      -.2957614
# 99%            1              1       Kurtosis       1.087475
#
#              ${\it User Incentive Increase}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .2717314
#                         Largest       Std. dev.      .4449308
# 75%            1              1
# 90%            1              1       Variance       .1979634
# 95%            1              1       Skewness       1.026267
# 99%            1              1       Kurtosis       2.053224
#
#                    ${\it Tokenomics}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            1                      Mean           .6469965
#                         Largest       Std. dev.      .4779883
# 75%            1              1
# 90%            1              1       Variance       .2284728
# 95%            1              1       Skewness      -.6151718
# 99%            1              1       Kurtosis       1.378436
#
#              ${\it Voting Mechanism Change}_{i}$
# -------------------------------------------------------------
#       Percentiles      Smallest
#  1%            0              0
#  5%            0              0
# 10%            0              0       Obs               2,830
# 25%            0              0       Sum of wgt.       2,830
#
# 50%            0                      Mean           .0466431
#                         Largest       Std. dev.      .2109105
# 75%            0              1
# 90%            0              1       Variance       .0444832
# 95%            0              1       Skewness       4.299805
# 99%            1              1       Kurtosis       19.48832
#
# .
# . * Export a nice LaTeX summary table with mean, SD, p10, median, p90
# . estpost summarize `cars' `participation' `wins' `proposal_char' `discussion_c
# > har' `user' `topic_char', detail
#
#              |  e(count)   e(sum_w)    e(mean)     e(Var)      e(sd)
# -------------+-------------------------------------------------------
#  car_created |      1593       1593  -.0183644   .0720932   .2685018
#      car_end |      1658       1658  -.0400436   .0468271   .2163957
# non_whale~on |      2667       2667   .0317196   .0020228   .0449758
# non_wha~y_vn |      2669       2669   .0678157   .0632404   .2514764
#     weighted |      2830       2830   .1339223   .1160281    .340629
# multi_choi~s |      2830       2830   .4226148   .2440978   .4940625
#       quorum |      2830       2830   .2992933   .2097909   .4580294
#   delegation |      2830       2830   .2636042   .1941857    .440665
# have_di~sion |      2830       2830    .395053   .2390706   .4889485
# concensus_~f |       581        581   .1357869   .1053622   .3245954
# non_whale_~r |      2439       2439   .5715484   .1796575   .4238602
# protocol_s~y |      2830       2830   .1028269   .0922861   .3037863
# treasury_e~e |      2830       2830   .5731449   .2447363   .4947083
# user_incen~e |      2830       2830   .2717314   .1979634   .4449308
#   tokenomics |      2830       2830   .6469965   .2284728   .4779883
# voting_mec~e |      2830       2830   .0466431   .0444832   .2109105
#
#              | e(skewn~)  e(kurto~)     e(sum)     e(min)     e(max)
# -------------+-------------------------------------------------------
#  car_created |  6.972902   148.0914  -29.25453  -1.076359   5.858808
#      car_end |  .1165242    5.60718  -66.39228  -1.000393   1.140595
# non_whale~on |  2.201079   8.810736   84.59625          0   .2484313
# non_wha~y_vn |   3.43782   12.81861        181          0          1
#     weighted |  2.149802   5.621649        379          0          1
# multi_choi~s |  .3133159   1.098167       1196          0          1
#       quorum |  .8765471   1.768335        847          0          1
#   delegation |  1.073094   2.151531        746          0          1
# have_di~sion |  .4293522   1.184343       1118          0          1
# concensus_~f |  .2865379   4.197167    78.8922  -.9866134   .9953478
# non_whale_~r | -.3714786    1.33276   1394.006          0          1
# protocol_s~y |  2.615282   7.839698        291          0          1
# treasury_e~e | -.2957614   1.087475       1622          0          1
# user_incen~e |  1.026267   2.053224        769          0          1
#   tokenomics | -.6151718   1.378436       1831          0          1
# voting_mec~e |  4.299805   19.48832        132          0          1
#
#              |     e(p1)      e(p5)     e(p10)     e(p25)     e(p50)
# -------------+-------------------------------------------------------
#  car_created | -.5506855  -.3886827  -.2914971  -.1241135   -.021734
#      car_end | -.6044713  -.4219742  -.3078582  -.1397889  -.0294226
# non_whale~on |         0          0   .0002275   .0023566   .0105513
# non_wha~y_vn |         0          0          0          0          0
#     weighted |         0          0          0          0          0
# multi_choi~s |         0          0          0          0          0
#       quorum |         0          0          0          0          0
#   delegation |         0          0          0          0          0
# have_di~sion |         0          0          0          0          0
# concensus_~f | -.7685081  -.3299616  -.1532581  -.0012337   .0379507
# non_whale_~r |         0          0          0   .0218978         .8
# protocol_s~y |         0          0          0          0          0
# treasury_e~e |         0          0          0          0          1
# user_incen~e |         0          0          0          0          0
#   tokenomics |         0          0          0          0          1
# voting_mec~e |         0          0          0          0          0
#
#              |    e(p75)     e(p90)     e(p95)     e(p99)
# -------------+--------------------------------------------
#  car_created |  .0630045   .2163358    .415639   .6221527
#      car_end |  .0631476   .2047631   .2875741   .5502529
# non_whale~on |  .0518732   .0852713   .1292439   .2484313
# non_wha~y_vn |         0          0          1          1
#     weighted |         0          1          1          1
# multi_choi~s |         1          1          1          1
#       quorum |         1          1          1          1
#   delegation |         1          1          1          1
# have_di~sion |         1          1          1          1
# concensus_~f |  .2910298   .6115506    .828934    .954693
# non_whale_~r |  .9634146          1          1          1
# protocol_s~y |         0          1          1          1
# treasury_e~e |         1          1          1          1
# user_incen~e |         1          1          1          1
#   tokenomics |         1          1          1          1
# voting_mec~e |         0          0          0          1
#
# . esttab using "$TABLES/summary_stats.tex", replace ///
# >     cells("count(fmt(0)) mean(fmt(3)) sd(fmt(3)) min(fmt(3)) p25(fmt(3)) p50(
# > fmt(3)) p75(fmt(3)) max(fmt(3))") ///
# >     collabels("Number of Obs." "Mean" "Std. Dev." "Min" "P25" "P50" "P75" "Ma
# > x") ///
# >     nonumber nomtitles noobs label ///
# >     alignment(D{.}{.}{-1}) booktabs ///
# >     compress nofloat nostar ///
# >     substitute("\_" "_")                     ///
# >     title("Summary Statistics of Variables") ///
# >     prehead("\begin{tabular}{l*{9}{c}}\toprule") ///
# >     posthead("\hline") ///
# >     postfoot("\bottomrule\end{tabular}")
# (output written to tables/summary_stats.tex)
#
# .
