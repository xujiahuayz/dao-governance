# %% [markdown]
# # Regression of Delegate Characteristics on CAR

# %%
import stata_setup

stata_setup.config('/Applications/StataNow', 'mp')

# %%
# %%stata
#
# clear all
# set more off
# set varabbrev off
# version 18
#
# * Paths
# global PROCESSED_DATA "processed_data"
# global TABLES "tables"
# Out:
# .
# . clear all
#
# . set more off
#
# . set varabbrev off
#
# . version 18
#
# .
# . * Paths
# . global PROCESSED_DATA "processed_data"
#
# . global TABLES "tables"
#
# .

# %%
# %%stata
# foreach stage in created end {
#     import delimited using "$PROCESSED_DATA/event_study_panel_`stage'.csv", clear
#
#     * Parse date
#     gen day = date(date, "YMD")
#     format day %td
#
#     * Create year variable
#     gen year = year(day)
#
#     * Create quarter variable
#     gen quarter = qofd(day)
#     format quarter %tq
#
#     * Ensure index is numeric (safeguard if it came in as string)
#     capture confirm numeric variable index
#     if _rc {
#         destring index, replace ignore("[]")
#     }
#
#     * Encode categorical variables
#     encode gecko_id, gen(token)
#     encode space,    gen(dao)
#
#     egen token_year = group(token year)
#     egen token_quarter = group(token quarter)
#
#     * Define windows and specs
#     local windows 2 5
#     local vars    delegate_dummy delegate
#
#     * Label variables
#     label variable delegate_dummy "\$\textit{Has Delegate}_{i,t}\$"
#     label variable delegate       "\$\textit{# of Delegates}_{i,t}\$"
#
#     eststo clear
#
#     foreach w of local windows {
#         preserve
#         keep if index == `w'
#
#         foreach v of local vars {
#             * Run regression
#             reghdfe car_`w' `v', absorb(token year) vce(cluster token)
#             eststo car`w'_`v'
#
#             * Tag FE rows (Y/N) for this spec
#             estadd local fe_token "Y"
#             estadd local fe_time  "Y"
#             estadd local fe_token_time   "N"
#             estadd local fe_dao   "N"
#         }
#
#         foreach v of local vars {
#             * Run regression
#             reghdfe car_`w' `v', absorb(token_year dao) vce(cluster token)
#             eststo car`w'_`v'_dao
#
#             * Tag FE rows (Y/N) for this spec
#             estadd local fe_token "N"
#             estadd local fe_time  "N"
#             estadd local fe_token_time   "Y"
#             estadd local fe_dao   "Y"
#         }
#
#         restore
#     }
#
#     * Export a single big LaTeX table
#     esttab                                                         ///
#         car2_delegate_dummy car2_delegate car2_delegate_dao car2_delegate      ///
#         car5_delegate_dummy car5_delegate car5_delegate_dao car5_delegate      ///
#         using "$TABLES/reg_car_delegate_`stage'.tex", replace      ///
#         se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///
#         nonotes booktabs nomtitles                                 ///
#         b(%9.3f) se(%9.2f)                                         ///
#         mgroups("CAR[-2,2]" "CAR[-5,5]",                           ///
#                 span                                               ///
#                 pattern(1 0 0 0 1 0 0 0)                                   ///
#                 prefix(\multicolumn{@span}{c}{)                    ///
#                 suffix(})                                          ///
#                 erepeat(\cmidrule(lr){@span}) )                    ///
#         substitute("\_" "_")                                       ///
#         stats(fe_token fe_time N r2_a,                             ///
#               fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Token-Year FE" "DAO FE" "Observations" "Adjusted R²"))
# }
# Out:
# . foreach stage in created end {
#   2.     import delimited using "$PROCESSED_DATA/event_study_panel_`stage'.csv"
# > , clear
#   3.
# .     * Parse date
# .     gen day = date(date, "YMD")
#   4.     format day %td
#   5.
# .     * Create year variable
# .     gen year = year(day)
#   6.
# .     * Create quarter variable
# .     gen quarter = qofd(day)
#   7.     format quarter %tq
#   8.
# .     * Ensure index is numeric (safeguard if it came in as string)
# .     capture confirm numeric variable index
#   9.     if _rc {
#  10.         destring index, replace ignore("[]")
#  11.     }
#  12.
# .     * Encode categorical variables
# .     encode gecko_id, gen(token)
#  13.     encode space,    gen(dao)
#  14.
# .     egen token_year = group(token year)
#  15.     egen token_quarter = group(token quarter)
#  16.
# .     * Define windows and specs
# .     local windows 2 5
#  17.     local vars    delegate_dummy delegate
#  18.
# .     * Label variables
# .     label variable delegate_dummy "\$\textit{Has Delegate}_{i,t}\$"
#  19.     label variable delegate       "\$\textit{# of Delegates}_{i,t}\$"
#  20.
# .     eststo clear
#  21.
# .     foreach w of local windows {
#  22.         preserve
#  23.         keep if index == `w'
#  24.
# .         foreach v of local vars {
#  25.             * Run regression
# .             reghdfe car_`w' `v', absorb(token year) vce(cluster token)
#  26.             eststo car`w'_`v'
#  27.
# .             * Tag FE rows (Y/N) for this spec
# .             estadd local fe_token "Y"
#  28.             estadd local fe_time  "Y"
#  29.             estadd local fe_token_time   "N"
#  30.             estadd local fe_dao   "N"
#  31.         }
#  32.
# .         foreach v of local vars {
#  33.             * Run regression
# .             reghdfe car_`w' `v', absorb(token_year dao) vce(cluster token)
#  34.             eststo car`w'_`v'_dao
#  35.
# .             * Tag FE rows (Y/N) for this spec
# .             estadd local fe_token "N"
#  36.             estadd local fe_time  "N"
#  37.             estadd local fe_token_time   "Y"
#  38.             estadd local fe_dao   "Y"
#  39.         }
#  40.
# .         restore
#  41.     }
#  42.
# .     * Export a single big LaTeX table
# .     esttab                                                         ///
# >         car2_delegate_dummy car2_delegate car2_delegate_dao car2_delegate
# >   ///
# >         car5_delegate_dummy car5_delegate car5_delegate_dao car5_delegate
# >   ///
# >         using "$TABLES/reg_car_delegate_`stage'.tex", replace      ///
# >         se star(* 0.10 ** 0.05 *** 0.01) label nogaps nocon        ///
# >         nonotes booktabs nomtitles                                 ///
# >         b(%9.3f) se(%9.2f)                                         ///
# >         mgroups("CAR[-2,2]" "CAR[-5,5]",                           ///
# >                 span                                               ///
# >                 pattern(1 0 0 0 1 0 0 0)                                   //
# > /
# >                 prefix(\multicolumn{@span}{c}{)                    ///
# >                 suffix(})                                          ///
# >                 erepeat(\cmidrule(lr){@span}) )                    ///
# >         substitute("\_" "_")                                       ///
# >         stats(fe_token fe_time N r2_a,                             ///
# >               fmt(0 0 %9.0fc %9.3f) labels("Token FE" "Year FE" "Token-Year F
# > E" "DAO FE" "Observations" "Adjusted R²"))
#  43. }
# (encoding automatically selected: ISO-8859-1)
# (45 vars, 10,780 obs)
# (9,800 observations deleted)
# (dropped 37 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        943
# Absorbing 2 HDFE groups                           F(   1,    145) =       0.14
# Statistics robust to heteroskedasticity           Prob > F        =     0.7070
#                                                   R-squared       =     0.1925
#                                                   Adj R-squared   =     0.0384
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        146         Root MSE        =     0.2006
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |  -.0104594   .0277697    -0.38   0.707     -.065345    .0444262
#        _cons |  -.0117285   .0007657   -15.32   0.000    -.0132418   -.0102152
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 37 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        943
# Absorbing 2 HDFE groups                           F(   1,    145) =       4.53
# Statistics robust to heteroskedasticity           Prob > F        =     0.0350
#                                                   R-squared       =     0.1928
#                                                   Adj R-squared   =     0.0387
#                                                   Within R-sq.    =     0.0004
# Number of clusters (token)   =        146         Root MSE        =     0.2006
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |  -.0038972   .0018311    -2.13   0.035    -.0075164    -.000278
#        _cons |  -.0116739   .0001612   -72.43   0.000    -.0119924   -.0113553
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 160 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        820
# Absorbing 2 HDFE groups                           F(   1,    129) =       0.07
# Statistics robust to heteroskedasticity           Prob > F        =     0.7957
#                                                   R-squared       =     0.3470
#                                                   Adj R-squared   =    -0.2294
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        130         Root MSE        =     0.1484
#
#                                 (Std. err. adjusted for 130 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |  -.0081875   .0315502    -0.26   0.796    -.0706104    .0542354
#        _cons |    -.00944   .0008465   -11.15   0.000    -.0111148   -.0077652
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       252         252           0    *|
#          dao |       132         132           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (dropped 160 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        820
# Absorbing 2 HDFE groups                           F(   1,    129) =       0.46
# Statistics robust to heteroskedasticity           Prob > F        =     0.5003
#                                                   R-squared       =     0.3470
#                                                   Adj R-squared   =    -0.2294
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        130         Root MSE        =     0.1484
#
#                                 (Std. err. adjusted for 130 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |   .0030993   .0045857     0.68   0.500    -.0059737    .0121722
#        _cons |  -.0098184   .0002349   -41.80   0.000    -.0102831   -.0093537
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       252         252           0    *|
#          dao |       132         132           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (9,800 observations deleted)
# (dropped 37 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        943
# Absorbing 2 HDFE groups                           F(   1,    145) =       0.63
# Statistics robust to heteroskedasticity           Prob > F        =     0.4276
#                                                   R-squared       =     0.1981
#                                                   Adj R-squared   =     0.0450
#                                                   Within R-sq.    =     0.0002
# Number of clusters (token)   =        146         Root MSE        =     0.3273
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |    .030018   .0377357     0.80   0.428     -.044565    .1046011
#        _cons |  -.0139195   .0010404   -13.38   0.000    -.0159758   -.0118631
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 37 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        943
# Absorbing 2 HDFE groups                           F(   1,    145) =       0.71
# Statistics robust to heteroskedasticity           Prob > F        =     0.4010
#                                                   R-squared       =     0.1980
#                                                   Adj R-squared   =     0.0449
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        146         Root MSE        =     0.3273
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |  -.0026563   .0031537    -0.84   0.401    -.0088895    .0035769
#        _cons |   -.012858   .0002776   -46.32   0.000    -.0134066   -.0123094
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 160 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        820
# Absorbing 2 HDFE groups                           F(   1,    129) =       0.38
# Statistics robust to heteroskedasticity           Prob > F        =     0.5364
#                                                   R-squared       =     0.3487
#                                                   Adj R-squared   =    -0.2262
#                                                   Within R-sq.    =     0.0002
# Number of clusters (token)   =        130         Root MSE        =     0.2537
#
#                                 (Std. err. adjusted for 130 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |   .0207187   .0334235     0.62   0.536    -.0454105     .086848
#        _cons |  -.0074783   .0008967    -8.34   0.000    -.0092525   -.0057041
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       252         252           0    *|
#          dao |       132         132           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (dropped 160 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        820
# Absorbing 2 HDFE groups                           F(   1,    129) =       0.01
# Statistics robust to heteroskedasticity           Prob > F        =     0.9262
#                                                   R-squared       =     0.3486
#                                                   Adj R-squared   =    -0.2264
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =        130         Root MSE        =     0.2538
#
#                                 (Std. err. adjusted for 130 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |   .0005406   .0058276     0.09   0.926    -.0109895    .0120707
#        _cons |  -.0069501   .0002985   -23.28   0.000    -.0075407   -.0063595
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       252         252           0    *|
#          dao |       132         132           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (output written to tables/reg_car_delegate_created.tex)
# (encoding automatically selected: ISO-8859-1)
# (45 vars, 10,725 obs)
# (9,750 observations deleted)
# (dropped 35 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        940
# Absorbing 2 HDFE groups                           F(   1,    145) =       0.37
# Statistics robust to heteroskedasticity           Prob > F        =     0.5450
#                                                   R-squared       =     0.2278
#                                                   Adj R-squared   =     0.0799
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        146         Root MSE        =     0.2398
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |  -.0135042   .0222599    -0.61   0.545    -.0575001    .0304917
#        _cons |  -.0119352    .000592   -20.16   0.000    -.0131053   -.0107651
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 35 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        940
# Absorbing 2 HDFE groups                           F(   1,    145) =       2.20
# Statistics robust to heteroskedasticity           Prob > F        =     0.1399
#                                                   R-squared       =     0.2279
#                                                   Adj R-squared   =     0.0799
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        146         Root MSE        =     0.2398
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |  -.0025742   .0017343    -1.48   0.140    -.0060019    .0008535
#        _cons |  -.0120698   .0001513   -79.78   0.000    -.0123688   -.0117708
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 159 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        816
# Absorbing 2 HDFE groups                           F(   1,    130) =       0.09
# Statistics robust to heteroskedasticity           Prob > F        =     0.7667
#                                                   R-squared       =     0.4403
#                                                   Adj R-squared   =    -0.0584
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =        131         Root MSE        =     0.2023
#
#                                 (Std. err. adjusted for 131 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |   .0087699   .0294927     0.30   0.767    -.0495779    .0671177
#        _cons |  -.0070887   .0007229    -9.81   0.000    -.0085188   -.0056586
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       251         251           0    *|
#          dao |       133         133           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (dropped 159 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        816
# Absorbing 2 HDFE groups                           F(   1,    130) =       2.00
# Statistics robust to heteroskedasticity           Prob > F        =     0.1593
#                                                   R-squared       =     0.4404
#                                                   Adj R-squared   =    -0.0583
#                                                   Within R-sq.    =     0.0001
# Number of clusters (token)   =        131         Root MSE        =     0.2023
#
#                                 (Std. err. adjusted for 131 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_2 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |    .004963   .0035062     1.42   0.159    -.0019735    .0118995
#        _cons |  -.0071109   .0001676   -42.43   0.000    -.0074424   -.0067794
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       251         251           0    *|
#          dao |       133         133           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (9,750 observations deleted)
# (dropped 35 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        940
# Absorbing 2 HDFE groups                           F(   1,    145) =       0.00
# Statistics robust to heteroskedasticity           Prob > F        =     0.9789
#                                                   R-squared       =     0.2001
#                                                   Adj R-squared   =     0.0468
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =        146         Root MSE        =     0.3501
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |  -.0009967   .0376393    -0.03   0.979    -.0753892    .0733958
#        _cons |  -.0247164    .001001   -24.69   0.000    -.0266949   -.0227379
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 35 singleton observations)
# (MWFE estimator converged in 7 iterations)
#
# HDFE Linear regression                            Number of obs   =        940
# Absorbing 2 HDFE groups                           F(   1,    145) =       0.04
# Statistics robust to heteroskedasticity           Prob > F        =     0.8473
#                                                   R-squared       =     0.2001
#                                                   Adj R-squared   =     0.0468
#                                                   Within R-sq.    =     0.0000
# Number of clusters (token)   =        146         Root MSE        =     0.3501
#
#                                 (Std. err. adjusted for 146 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |  -.0006791   .0035201    -0.19   0.847    -.0076364    .0062782
#        _cons |  -.0246836   .0003071   -80.38   0.000    -.0252906   -.0240767
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        token |       146         146           0    *|
#         year |         6           1           5     |
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "Y"
#
# added macro:
#             e(fe_time) : "Y"
#
# added macro:
#       e(fe_token_time) : "N"
#
# added macro:
#              e(fe_dao) : "N"
# (dropped 159 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        816
# Absorbing 2 HDFE groups                           F(   1,    130) =       1.03
# Statistics robust to heteroskedasticity           Prob > F        =     0.3116
#                                                   R-squared       =     0.3998
#                                                   Adj R-squared   =    -0.1376
#                                                   Within R-sq.    =     0.0008
# Number of clusters (token)   =        131         Root MSE        =     0.2420
#
#                                 (Std. err. adjusted for 131 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# delegate_d~y |   .0463842   .0456573     1.02   0.312    -.0439433    .1367117
#        _cons |  -.0155732   .0011191   -13.92   0.000    -.0177871   -.0133593
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       252         252           0    *|
#          dao |       133         133           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (dropped 159 singleton observations)
# (MWFE estimator converged in 3 iterations)
#
# HDFE Linear regression                            Number of obs   =        816
# Absorbing 2 HDFE groups                           F(   1,    130) =      15.99
# Statistics robust to heteroskedasticity           Prob > F        =     0.0001
#                                                   R-squared       =     0.4002
#                                                   Adj R-squared   =    -0.1369
#                                                   Within R-sq.    =     0.0014
# Number of clusters (token)   =        131         Root MSE        =     0.2419
#
#                                 (Std. err. adjusted for 131 clusters in token)
# ------------------------------------------------------------------------------
#              |               Robust
#        car_5 | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#     delegate |   .0187609   .0046912     4.00   0.000       .00948    .0280418
#        _cons |   -.015333   .0002242   -68.39   0.000    -.0157766   -.0148894
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#   token_year |       252         252           0    *|
#          dao |       133         133           0    *|
# -----------------------------------------------------+
# * = FE nested within cluster; treated as redundant for DoF computation
#
# added macro:
#            e(fe_token) : "N"
#
# added macro:
#             e(fe_time) : "N"
#
# added macro:
#       e(fe_token_time) : "Y"
#
# added macro:
#              e(fe_dao) : "Y"
# (output written to tables/reg_car_delegate_end.tex)
#
# .
